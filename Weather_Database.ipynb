# %%
# Import the dependencies
import pandas as pd
import numpy as np

# Use the citipy module to determine city based on latitude and longitude
from citipy import citipy

# Import the requests library
import requests

# Import the API key
from config import weather_api_key

# %%
# Creating a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Creating a list with the random latitudes and longitudes
coordinates = list(lat_lngs)

# %%
# Creating a list to hold the nearest cities
cities = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 621

# %%
# Perform API call with Open Weather Map
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city that might have rain to figure out how to parse the JSON for
# rain in the last hour
city_url = url + "&q=" + "Toronto"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=341aca6b382978ac3c45b49bd2416709&q=Toronto

# %%
# Create an endpoint URL for a city that might have snow to figure out how to parse the JSON for
# rain in the last hour
city_url = url + "&q=" + "Alert"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=341aca6b382978ac3c45b49bd2416709&q=Alert

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        
    

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass


    
    # Running a next try-except block to get cities that had rainfall in the last hour
    # If not, setting rainfall= 0
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_rain_1h = city_weather["rain"]["1h"]
        

    # If an error is experienced, rainfall = 0.
    except:
        city_rain_1h = 0
        pass    


    

    # Running a next try-except block to get cities that had snowl in the last hour
    # Not many cities around the world will have snow especially given this time of year
    # If not, setting snow = 0
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_snow_1h = city_weather["snow"]["1h"]
        

    # If an error is experienced, snow = 0.
    except:
        city_snow_1h = 0
        pass   


        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Rain(inches)": city_rain_1h,
                          "Snow(inches)": city_snow_1h})
        
        
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | san andres
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | kruisfontein
# Processing Record 4 of Set 1 | vestmannaeyjar
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | severo-kurilsk
# Processing Record 8 of Set 1 | kulhudhuffushi
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | danville
# Processing Record 12 of Set 1 | opobo
# City not found. Skipping...
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 1 | longyearbyen
# Processing Record 17 of Set 1 | qaanaaq
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | leeton
# Processing Record 20 of Set 1 | la union
# Processing Record 21 of Set 1 | narsaq
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | chokurdakh
# Processing Record 25 of Set 1 | san cristobal
# Processing Record 26 of Set 1 | yashkino
# Processing Record 27 of Set 1 | alice springs
# Processing Record 28 of Set 1 | san patricio
# Processing Record 29 of Set 1 | lagoa
# Processing Record 30 of Set 1 | sur
# Processing Record 31 of Set 1 | banjar
# Processing Record 32 of Set 1 | hilo
# Processing Record 33 of Set 1 | yellowknife
# Processing Record 34 of Set 1 | lebu
# Processing Record 35 of Set 1 | cayenne
# Processing Record 36 of Set 1 | ngunguru
# Processing Record 37 of Set 1 | pangody
# Processing Record 38 of Set 1 | bengkulu
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | oranjemund
# Processing Record 42 of Set 1 | te anau
# Processing Record 43 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 1 | kalianget
# Processing Record 45 of Set 1 | port lincoln
# Processing Record 46 of Set 1 | guerrero negro
# Processing Record 47 of Set 1 | katsuura
# Processing Record 48 of Set 1 | camacha
# Processing Record 49 of Set 1 | mount isa
# Processing Record 50 of Set 1 | puerto ayora
# Processing Record 1 of Set 2 | hithadhoo
# Processing Record 2 of Set 2 | coquimbo
# Processing Record 3 of Set 2 | jonesboro
# Processing Record 4 of Set 2 | abaza
# Processing Record 5 of Set 2 | waipawa
# Processing Record 6 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 2 | ciamis
# Processing Record 8 of Set 2 | ahuimanu
# Processing Record 9 of Set 2 | ribeira grande
# Processing Record 10 of Set 2 | east london
# Processing Record 11 of Set 2 | coihaique
# Processing Record 12 of Set 2 | portland
# Processing Record 13 of Set 2 | khatanga
# Processing Record 14 of Set 2 | butaritari
# Processing Record 15 of Set 2 | wattegama
# Processing Record 16 of Set 2 | tessalit
# Processing Record 17 of Set 2 | torbay
# Processing Record 18 of Set 2 | comodoro rivadavia
# Processing Record 19 of Set 2 | sitka
# Processing Record 20 of Set 2 | norman wells
# Processing Record 21 of Set 2 | georgetown
# Processing Record 22 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 2 | atuona
# Processing Record 25 of Set 2 | kaeo
# Processing Record 26 of Set 2 | methoni
# Processing Record 27 of Set 2 | maarianhamina
# Processing Record 28 of Set 2 | kapaa
# Processing Record 29 of Set 2 | hermanus
# Processing Record 30 of Set 2 | bonavista
# Processing Record 31 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 2 | pevek
# Processing Record 34 of Set 2 | raudeberg
# Processing Record 35 of Set 2 | leningradskiy
# Processing Record 36 of Set 2 | vestmanna
# Processing Record 37 of Set 2 | chuy
# Processing Record 38 of Set 2 | saskylakh
# Processing Record 39 of Set 2 | mariara
# Processing Record 40 of Set 2 | plettenberg bay
# Processing Record 41 of Set 2 | dingle
# Processing Record 42 of Set 2 | gazli
# Processing Record 43 of Set 2 | mahebourg
# Processing Record 44 of Set 2 | albany
# Processing Record 45 of Set 2 | bambous virieux
# Processing Record 46 of Set 2 | fairbanks
# Processing Record 47 of Set 2 | los llanos de aridane
# Processing Record 48 of Set 2 | powell river
# Processing Record 49 of Set 2 | saint-philippe
# Processing Record 50 of Set 2 | baculin
# Processing Record 1 of Set 3 | saint george
# Processing Record 2 of Set 3 | sinkat
# City not found. Skipping...
# Processing Record 3 of Set 3 | sofiysk
# City not found. Skipping...
# Processing Record 4 of Set 3 | brigantine
# Processing Record 5 of Set 3 | patea
# Processing Record 6 of Set 3 | aviles
# Processing Record 7 of Set 3 | alofi
# Processing Record 8 of Set 3 | sydney
# Processing Record 9 of Set 3 | yerbogachen
# Processing Record 10 of Set 3 | sataua
# City not found. Skipping...
# Processing Record 11 of Set 3 | shelburne
# Processing Record 12 of Set 3 | anadyr
# Processing Record 13 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 3 | nemuro
# Processing Record 15 of Set 3 | vardo
# Processing Record 16 of Set 3 | talnakh
# Processing Record 17 of Set 3 | sedelnikovo
# City not found. Skipping...
# Processing Record 18 of Set 3 | mogadishu
# Processing Record 19 of Set 3 | natchez
# Processing Record 20 of Set 3 | port elizabeth
# Processing Record 21 of Set 3 | tuktoyaktuk
# Processing Record 22 of Set 3 | bluff
# Processing Record 23 of Set 3 | gawler
# Processing Record 24 of Set 3 | salalah
# Processing Record 25 of Set 3 | suntar
# Processing Record 26 of Set 3 | mocuba
# Processing Record 27 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 29 of Set 3 | klaksvik
# Processing Record 30 of Set 3 | apodi
# Processing Record 31 of Set 3 | arraial do cabo
# Processing Record 32 of Set 3 | berbera
# Processing Record 33 of Set 3 | barrow
# Processing Record 34 of Set 3 | mehamn
# Processing Record 35 of Set 3 | gumia
# Processing Record 36 of Set 3 | ahipara
# Processing Record 37 of Set 3 | labytnangi
# Processing Record 38 of Set 3 | kodinsk
# Processing Record 39 of Set 3 | patratu
# City not found. Skipping...
# Processing Record 40 of Set 3 | bonthe
# Processing Record 41 of Set 3 | kaitangata
# Processing Record 42 of Set 3 | fortuna
# Processing Record 43 of Set 3 | havre-saint-pierre
# Processing Record 44 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 3 | mabaruma
# Processing Record 46 of Set 3 | janakpur road
# City not found. Skipping...
# Processing Record 47 of Set 3 | sirsa
# Processing Record 48 of Set 3 | port augusta
# Processing Record 49 of Set 3 | karakendzha
# City not found. Skipping...
# Processing Record 50 of Set 3 | cherskiy
# Processing Record 1 of Set 4 | enshi
# Processing Record 2 of Set 4 | lubango
# Processing Record 3 of Set 4 | vila do maio
# Processing Record 4 of Set 4 | saldanha
# Processing Record 5 of Set 4 | krasnogvardeyskoye
# Processing Record 6 of Set 4 | beringovskiy
# Processing Record 7 of Set 4 | jaranwala
# Processing Record 8 of Set 4 | upernavik
# Processing Record 9 of Set 4 | new norfolk
# Processing Record 10 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 11 of Set 4 | bay roberts
# Processing Record 12 of Set 4 | geraldton
# Processing Record 13 of Set 4 | veraval
# Processing Record 14 of Set 4 | ruteng
# Processing Record 15 of Set 4 | sao filipe
# Processing Record 16 of Set 4 | key largo
# Processing Record 17 of Set 4 | solnechnyy
# Processing Record 18 of Set 4 | nanortalik
# Processing Record 19 of Set 4 | lompoc
# Processing Record 20 of Set 4 | ulladulla
# Processing Record 21 of Set 4 | lavrentiya
# Processing Record 22 of Set 4 | minyar
# Processing Record 23 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 24 of Set 4 | avarua
# Processing Record 25 of Set 4 | de aar
# Processing Record 26 of Set 4 | la tuque
# Processing Record 27 of Set 4 | deputatskiy
# Processing Record 28 of Set 4 | mar del plata
# Processing Record 29 of Set 4 | anito
# Processing Record 30 of Set 4 | salamiyah
# Processing Record 31 of Set 4 | anton lizardo
# Processing Record 32 of Set 4 | menongue
# Processing Record 33 of Set 4 | grand gaube
# Processing Record 34 of Set 4 | verkhnevilyuysk
# Processing Record 35 of Set 4 | greenwood
# Processing Record 36 of Set 4 | tasiilaq
# Processing Record 37 of Set 4 | yanchukan
# City not found. Skipping...
# Processing Record 38 of Set 4 | hirara
# Processing Record 39 of Set 4 | polewali
# Processing Record 40 of Set 4 | adrar
# Processing Record 41 of Set 4 | kodiak
# Processing Record 42 of Set 4 | shuyskoye
# Processing Record 43 of Set 4 | xining
# Processing Record 44 of Set 4 | isangel
# Processing Record 45 of Set 4 | buala
# Processing Record 46 of Set 4 | steamboat springs
# Processing Record 47 of Set 4 | devli
# Processing Record 48 of Set 4 | kiama
# Processing Record 49 of Set 4 | merke
# Processing Record 50 of Set 4 | leh
# Processing Record 1 of Set 5 | vulcan
# Processing Record 2 of Set 5 | port macquarie
# Processing Record 3 of Set 5 | hamilton
# Processing Record 4 of Set 5 | tiksi
# Processing Record 5 of Set 5 | snasa
# Processing Record 6 of Set 5 | ambilobe
# Processing Record 7 of Set 5 | kenora
# Processing Record 8 of Set 5 | kangaatsiaq
# Processing Record 9 of Set 5 | thompson
# Processing Record 10 of Set 5 | carnarvon
# Processing Record 11 of Set 5 | nenjiang
# Processing Record 12 of Set 5 | keokuk
# Processing Record 13 of Set 5 | cuitareo
# Processing Record 14 of Set 5 | rawson
# Processing Record 15 of Set 5 | auki
# Processing Record 16 of Set 5 | novosergiyevka
# Processing Record 17 of Set 5 | freudenstadt
# Processing Record 18 of Set 5 | sorong
# Processing Record 19 of Set 5 | nikolskoye
# Processing Record 20 of Set 5 | emba
# Processing Record 21 of Set 5 | windhoek
# Processing Record 22 of Set 5 | castro
# Processing Record 23 of Set 5 | pacific grove
# Processing Record 24 of Set 5 | atar
# Processing Record 25 of Set 5 | gidam
# Processing Record 26 of Set 5 | bethel
# Processing Record 27 of Set 5 | mahibadhoo
# Processing Record 28 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 5 | caravelas
# Processing Record 30 of Set 5 | daan
# Processing Record 31 of Set 5 | dicabisagan
# Processing Record 32 of Set 5 | umm kaddadah
# Processing Record 33 of Set 5 | porto novo
# Processing Record 34 of Set 5 | shasta lake
# Processing Record 35 of Set 5 | barra patuca
# Processing Record 36 of Set 5 | hurghada
# Processing Record 37 of Set 5 | valley station
# Processing Record 38 of Set 5 | kyren
# Processing Record 39 of Set 5 | moron
# Processing Record 40 of Set 5 | souillac
# Processing Record 41 of Set 5 | dudinka
# Processing Record 42 of Set 5 | meiktila
# Processing Record 43 of Set 5 | yandyki
# Processing Record 44 of Set 5 | luderitz
# Processing Record 45 of Set 5 | formosa
# Processing Record 46 of Set 5 | meulaboh
# Processing Record 47 of Set 5 | moshenskoye
# Processing Record 48 of Set 5 | huicheng
# Processing Record 49 of Set 5 | honolulu
# Processing Record 50 of Set 5 | jinchang
# Processing Record 1 of Set 6 | kavieng
# Processing Record 2 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 6 | victor harbor
# Processing Record 4 of Set 6 | swan river
# Processing Record 5 of Set 6 | den helder
# Processing Record 6 of Set 6 | bayan
# Processing Record 7 of Set 6 | portoferraio
# Processing Record 8 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 9 of Set 6 | muros
# Processing Record 10 of Set 6 | blagodatnoye
# Processing Record 11 of Set 6 | jeremoabo
# Processing Record 12 of Set 6 | wagga wagga
# Processing Record 13 of Set 6 | asau
# Processing Record 14 of Set 6 | daru
# Processing Record 15 of Set 6 | korla
# Processing Record 16 of Set 6 | hokitika
# Processing Record 17 of Set 6 | talavera de la reina
# Processing Record 18 of Set 6 | nuevo progreso
# Processing Record 19 of Set 6 | koutsouras
# Processing Record 20 of Set 6 | itarema
# Processing Record 21 of Set 6 | vao
# Processing Record 22 of Set 6 | kichera
# Processing Record 23 of Set 6 | mumbwa
# Processing Record 24 of Set 6 | sabzevar
# Processing Record 25 of Set 6 | porto velho
# Processing Record 26 of Set 6 | haines junction
# Processing Record 27 of Set 6 | fukue
# Processing Record 28 of Set 6 | tuni
# Processing Record 29 of Set 6 | ancud
# Processing Record 30 of Set 6 | tapaua
# City not found. Skipping...
# Processing Record 31 of Set 6 | cidreira
# Processing Record 32 of Set 6 | samandag
# Processing Record 33 of Set 6 | kalach-na-donu
# Processing Record 34 of Set 6 | urumqi
# Processing Record 35 of Set 6 | fauldhouse
# Processing Record 36 of Set 6 | lagos
# Processing Record 37 of Set 6 | mazyr
# Processing Record 38 of Set 6 | ilulissat
# Processing Record 39 of Set 6 | dikson
# Processing Record 40 of Set 6 | ternate
# Processing Record 41 of Set 6 | teguldet
# Processing Record 42 of Set 6 | bombay
# Processing Record 43 of Set 6 | saint augustine
# Processing Record 44 of Set 6 | mogapinyana
# Processing Record 45 of Set 6 | cabo san lucas
# Processing Record 46 of Set 6 | aksarka
# Processing Record 47 of Set 6 | spencer
# Processing Record 48 of Set 6 | nerchinskiy zavod
# Processing Record 49 of Set 6 | payson
# Processing Record 50 of Set 6 | manitouwadge
# Processing Record 1 of Set 7 | alekseyevka
# Processing Record 2 of Set 7 | terrasini
# Processing Record 3 of Set 7 | kahului
# Processing Record 4 of Set 7 | lensk
# Processing Record 5 of Set 7 | maniitsoq
# Processing Record 6 of Set 7 | fengcheng
# Processing Record 7 of Set 7 | airai
# Processing Record 8 of Set 7 | sinnamary
# Processing Record 9 of Set 7 | kloulklubed
# Processing Record 10 of Set 7 | la ronge
# Processing Record 11 of Set 7 | rocha
# Processing Record 12 of Set 7 | chauk
# Processing Record 13 of Set 7 | lufilufi
# Processing Record 14 of Set 7 | ewa beach
# Processing Record 15 of Set 7 | saint-augustin
# Processing Record 16 of Set 7 | henties bay
# Processing Record 17 of Set 7 | barranca
# Processing Record 18 of Set 7 | gurskoye
# City not found. Skipping...
# Processing Record 19 of Set 7 | kanye
# Processing Record 20 of Set 7 | mount gambier
# Processing Record 21 of Set 7 | yima
# Processing Record 22 of Set 7 | carutapera
# Processing Record 23 of Set 7 | kemijarvi
# Processing Record 24 of Set 7 | odweyne
# Processing Record 25 of Set 7 | hay river
# Processing Record 26 of Set 7 | sao joao da barra
# Processing Record 27 of Set 7 | shizuishan
# Processing Record 28 of Set 7 | arambagh
# Processing Record 29 of Set 7 | kholmy
# Processing Record 30 of Set 7 | chicama
# Processing Record 31 of Set 7 | sao gabriel da cachoeira
# Processing Record 32 of Set 7 | qiongshan
# Processing Record 33 of Set 7 | mingaora
# Processing Record 34 of Set 7 | shitanjing
# Processing Record 35 of Set 7 | strezhevoy
# Processing Record 36 of Set 7 | tarakan
# Processing Record 37 of Set 7 | jiuquan
# Processing Record 38 of Set 7 | kushmurun
# Processing Record 39 of Set 7 | krumovgrad
# Processing Record 40 of Set 7 | berlevag
# Processing Record 41 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 42 of Set 7 | redmond
# Processing Record 43 of Set 7 | faanui
# Processing Record 44 of Set 7 | ponta do sol
# Processing Record 45 of Set 7 | sapele
# Processing Record 46 of Set 7 | rudbar
# Processing Record 47 of Set 7 | buritis
# Processing Record 48 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 49 of Set 7 | omaruru
# Processing Record 50 of Set 7 | impfondo
# Processing Record 1 of Set 8 | dwarka
# Processing Record 2 of Set 8 | guarapari
# Processing Record 3 of Set 8 | kuching
# Processing Record 4 of Set 8 | salta
# Processing Record 5 of Set 8 | san jeronimo
# Processing Record 6 of Set 8 | cap malheureux
# Processing Record 7 of Set 8 | codrington
# Processing Record 8 of Set 8 | carver
# Processing Record 9 of Set 8 | port blair
# Processing Record 10 of Set 8 | bend
# Processing Record 11 of Set 8 | lucapa
# Processing Record 12 of Set 8 | garavuti
# Processing Record 13 of Set 8 | hasaki
# Processing Record 14 of Set 8 | malpe
# Processing Record 15 of Set 8 | aykhal
# Processing Record 16 of Set 8 | iqaluit
# Processing Record 17 of Set 8 | vostok
# Processing Record 18 of Set 8 | khani
# Processing Record 19 of Set 8 | khorixas
# Processing Record 20 of Set 8 | maragogi
# Processing Record 21 of Set 8 | doha
# Processing Record 22 of Set 8 | winneba
# Processing Record 23 of Set 8 | george town
# Processing Record 24 of Set 8 | whitianga
# Processing Record 25 of Set 8 | acapulco
# Processing Record 26 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 8 | yunjinghong
# City not found. Skipping...
# Processing Record 28 of Set 8 | lorengau
# Processing Record 29 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 31 of Set 8 | parana
# Processing Record 32 of Set 8 | kalmunai
# Processing Record 33 of Set 8 | xianyang
# Processing Record 34 of Set 8 | myitkyina
# Processing Record 35 of Set 8 | antalya
# Processing Record 36 of Set 8 | touros
# Processing Record 37 of Set 8 | bilibino
# Processing Record 38 of Set 8 | sisimiut
# Processing Record 39 of Set 8 | the valley
# Processing Record 40 of Set 8 | weiz
# Processing Record 41 of Set 8 | antonina
# Processing Record 42 of Set 8 | provideniya
# Processing Record 43 of Set 8 | smoky lake
# Processing Record 44 of Set 8 | golden rock
# City not found. Skipping...
# Processing Record 45 of Set 8 | aguimes
# Processing Record 46 of Set 8 | lebedinyy
# Processing Record 47 of Set 8 | mehtar lam
# Processing Record 48 of Set 8 | pangkalanbuun
# Processing Record 49 of Set 8 | francistown
# Processing Record 50 of Set 8 | tuatapere
# Processing Record 1 of Set 9 | chivolo
# Processing Record 2 of Set 9 | port hardy
# Processing Record 3 of Set 9 | saint-joseph
# Processing Record 4 of Set 9 | kokopo
# Processing Record 5 of Set 9 | ola
# Processing Record 6 of Set 9 | nalut
# Processing Record 7 of Set 9 | manakara
# Processing Record 8 of Set 9 | saryozek
# Processing Record 9 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 9 | tikhvin
# Processing Record 11 of Set 9 | bodden town
# Processing Record 12 of Set 9 | bilma
# Processing Record 13 of Set 9 | ajaccio
# Processing Record 14 of Set 9 | sonqor
# Processing Record 15 of Set 9 | laredo
# Processing Record 16 of Set 9 | north platte
# Processing Record 17 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 9 | tabat
# Processing Record 19 of Set 9 | broome
# Processing Record 20 of Set 9 | hervey bay
# Processing Record 21 of Set 9 | ucluelet
# Processing Record 22 of Set 9 | ambon
# Processing Record 23 of Set 9 | teya
# Processing Record 24 of Set 9 | dujuma
# City not found. Skipping...
# Processing Record 25 of Set 9 | ibra
# Processing Record 26 of Set 9 | zhanatas
# City not found. Skipping...
# Processing Record 27 of Set 9 | laem sing
# Processing Record 28 of Set 9 | sao miguel do araguaia
# Processing Record 29 of Set 9 | mugur-aksy
# Processing Record 30 of Set 9 | northam
# Processing Record 31 of Set 9 | nome
# Processing Record 32 of Set 9 | omsukchan
# Processing Record 33 of Set 9 | teknaf
# Processing Record 34 of Set 9 | hambantota
# Processing Record 35 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 9 | high level
# Processing Record 37 of Set 9 | bogorodskoye
# Processing Record 38 of Set 9 | aldama
# Processing Record 39 of Set 9 | faya
# Processing Record 40 of Set 9 | rawlins
# Processing Record 41 of Set 9 | macae
# Processing Record 42 of Set 9 | havre de grace
# Processing Record 43 of Set 9 | proddatur
# Processing Record 44 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 9 | arman
# Processing Record 46 of Set 9 | pombas
# Processing Record 47 of Set 9 | bulungu
# Processing Record 48 of Set 9 | sioux lookout
# Processing Record 49 of Set 9 | kantunilkin
# Processing Record 50 of Set 9 | lahaina
# Processing Record 1 of Set 10 | sharon
# Processing Record 2 of Set 10 | pathalgaon
# Processing Record 3 of Set 10 | vytegra
# Processing Record 4 of Set 10 | eydhafushi
# Processing Record 5 of Set 10 | acin
# City not found. Skipping...
# Processing Record 6 of Set 10 | iracoubo
# Processing Record 7 of Set 10 | beloha
# Processing Record 8 of Set 10 | raga
# Processing Record 9 of Set 10 | halifax
# Processing Record 10 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 11 of Set 10 | hollins
# Processing Record 12 of Set 10 | uzhur
# Processing Record 13 of Set 10 | husavik
# Processing Record 14 of Set 10 | vanimo
# Processing Record 15 of Set 10 | lata
# Processing Record 16 of Set 10 | melnikovo
# Processing Record 17 of Set 10 | margate
# Processing Record 18 of Set 10 | prince rupert
# Processing Record 19 of Set 10 | mana
# Processing Record 20 of Set 10 | laela
# Processing Record 21 of Set 10 | jawhar
# Processing Record 22 of Set 10 | akdepe
# Processing Record 23 of Set 10 | sambava
# Processing Record 24 of Set 10 | orbetello
# Processing Record 25 of Set 10 | klyuchi
# Processing Record 26 of Set 10 | siniscola
# Processing Record 27 of Set 10 | muli
# Processing Record 28 of Set 10 | mwense
# Processing Record 29 of Set 10 | genhe
# Processing Record 30 of Set 10 | sarangani
# Processing Record 31 of Set 10 | monte carmelo
# Processing Record 32 of Set 10 | nyurba
# Processing Record 33 of Set 10 | traiguen
# Processing Record 34 of Set 10 | thinadhoo
# Processing Record 35 of Set 10 | gardan diwal
# City not found. Skipping...
# Processing Record 36 of Set 10 | penarth
# Processing Record 37 of Set 10 | kamina
# Processing Record 38 of Set 10 | viedma
# Processing Record 39 of Set 10 | lloydminster
# Processing Record 40 of Set 10 | batsfjord
# Processing Record 41 of Set 10 | padang
# Processing Record 42 of Set 10 | coahuayana
# Processing Record 43 of Set 10 | khargone
# Processing Record 44 of Set 10 | ribeira brava
# Processing Record 45 of Set 10 | tromso
# Processing Record 46 of Set 10 | evensk
# Processing Record 47 of Set 10 | aswan
# Processing Record 48 of Set 10 | bousso
# Processing Record 49 of Set 10 | kendari
# Processing Record 50 of Set 10 | harrison
# Processing Record 1 of Set 11 | zlobin
# Processing Record 2 of Set 11 | zhigansk
# Processing Record 3 of Set 11 | cabra
# Processing Record 4 of Set 11 | rupert
# Processing Record 5 of Set 11 | westport
# Processing Record 6 of Set 11 | tiznit
# Processing Record 7 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 8 of Set 11 | naze
# Processing Record 9 of Set 11 | vaitape
# Processing Record 10 of Set 11 | media luna
# Processing Record 11 of Set 11 | oktyabrskiy
# Processing Record 12 of Set 11 | igrim
# Processing Record 13 of Set 11 | gimli
# Processing Record 14 of Set 11 | santa maria del oro
# Processing Record 15 of Set 11 | kurumkan
# Processing Record 16 of Set 11 | huilong
# Processing Record 17 of Set 11 | apiai
# Processing Record 18 of Set 11 | burica
# City not found. Skipping...
# Processing Record 19 of Set 11 | xichang
# Processing Record 20 of Set 11 | san pedro
# Processing Record 21 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 11 | general roca
# Processing Record 23 of Set 11 | lima
# Processing Record 24 of Set 11 | cockburn town
# Processing Record 25 of Set 11 | mwingi
# Processing Record 26 of Set 11 | stephenville
# Processing Record 27 of Set 11 | gat
# Processing Record 28 of Set 11 | diamantino
# Processing Record 29 of Set 11 | esperance
# Processing Record 30 of Set 11 | kavos
# Processing Record 31 of Set 11 | chandbali
# Processing Record 32 of Set 11 | puerto escondido
# Processing Record 33 of Set 11 | venado tuerto
# Processing Record 34 of Set 11 | charters towers
# Processing Record 35 of Set 11 | vila franca do campo
# Processing Record 36 of Set 11 | upata
# Processing Record 37 of Set 11 | tongchuan
# Processing Record 38 of Set 11 | luganville
# Processing Record 39 of Set 11 | norden
# Processing Record 40 of Set 11 | barra
# Processing Record 41 of Set 11 | lujan
# Processing Record 42 of Set 11 | aksha
# Processing Record 43 of Set 11 | praia
# Processing Record 44 of Set 11 | nuuk
# Processing Record 45 of Set 11 | tazovskiy
# Processing Record 46 of Set 11 | gornopravdinsk
# Processing Record 47 of Set 11 | sibanicu
# Processing Record 48 of Set 11 | evanston
# Processing Record 49 of Set 11 | jumla
# Processing Record 50 of Set 11 | limon
# Processing Record 1 of Set 12 | constitucion
# Processing Record 2 of Set 12 | kabwe
# Processing Record 3 of Set 12 | inta
# Processing Record 4 of Set 12 | ouesso
# Processing Record 5 of Set 12 | lazaro cardenas
# Processing Record 6 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 12 | saint-georges
# Processing Record 8 of Set 12 | prieska
# Processing Record 9 of Set 12 | buchanan
# Processing Record 10 of Set 12 | tayshet
# Processing Record 11 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 12 | takoradi
# Processing Record 13 of Set 12 | atasu
# Processing Record 14 of Set 12 | ishigaki
# Processing Record 15 of Set 12 | orobo
# Processing Record 16 of Set 12 | tomatlan
# Processing Record 17 of Set 12 | agadez
# Processing Record 18 of Set 12 | ati
# Processing Record 19 of Set 12 | maputo
# Processing Record 20 of Set 12 | marawi
# Processing Record 21 of Set 12 | port hedland
# Processing Record 22 of Set 12 | zanjan
# Processing Record 23 of Set 12 | laguna
# Processing Record 24 of Set 12 | abancay
# Processing Record 25 of Set 12 | mackay
# Processing Record 26 of Set 12 | canoas
# Processing Record 27 of Set 12 | nurlat
# Processing Record 28 of Set 12 | antofagasta
# Processing Record 29 of Set 12 | taoudenni
# Processing Record 30 of Set 12 | kota kinabalu
# Processing Record 31 of Set 12 | saltpond
# Processing Record 32 of Set 12 | betamcherla
# Processing Record 33 of Set 12 | gitarama
# Processing Record 34 of Set 12 | tibiri
# Processing Record 35 of Set 12 | balsas
# Processing Record 36 of Set 12 | sao joao do piaui
# Processing Record 37 of Set 12 | simao
# Processing Record 38 of Set 12 | at-bashi
# Processing Record 39 of Set 12 | cedar city
# Processing Record 40 of Set 12 | kapit
# Processing Record 41 of Set 12 | surt
# Processing Record 42 of Set 12 | suhbaatar
# Processing Record 43 of Set 12 | tezu
# Processing Record 44 of Set 12 | namibe
# Processing Record 45 of Set 12 | bagdarin
# Processing Record 46 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 47 of Set 12 | baglan
# Processing Record 48 of Set 12 | three hills
# Processing Record 49 of Set 12 | ballina
# Processing Record 50 of Set 12 | peniche
# Processing Record 1 of Set 13 | kununurra
# Processing Record 2 of Set 13 | koumac
# Processing Record 3 of Set 13 | seymchan
# Processing Record 4 of Set 13 | kungurtug
# Processing Record 5 of Set 13 | martapura
# Processing Record 6 of Set 13 | gizo
# Processing Record 7 of Set 13 | kharian
# Processing Record 8 of Set 13 | labrea
# Processing Record 9 of Set 13 | tahta
# Processing Record 10 of Set 13 | kavaratti
# Processing Record 11 of Set 13 | algiers
# Processing Record 12 of Set 13 | okmulgee
# Processing Record 13 of Set 13 | imbituba
# Processing Record 14 of Set 13 | bacuit
# City not found. Skipping...
# Processing Record 15 of Set 13 | santiago del estero
# Processing Record 16 of Set 13 | kabarnet
# Processing Record 17 of Set 13 | ust-kut
# Processing Record 18 of Set 13 | lafia
# Processing Record 19 of Set 13 | estelle
# Processing Record 20 of Set 13 | aranos
# Processing Record 21 of Set 13 | lashio
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 621

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0      San Andres      CO  12.58  -81.70     78.80        88          75
# 1       Cape Town      ZA -33.93   18.42     66.00        45           0
# 2    Kruisfontein      ZA -34.00   24.73     65.34        27           0
# 3  Vestmannaeyjar      IS  63.44  -20.27     51.80        87          90
# 4         Ushuaia      AR -54.80  -68.30     35.60        80          75
# 5      Bredasdorp      ZA -34.53   20.04     66.20        37           0
# 6  Severo-Kurilsk      RU  50.68  156.12     49.33        91         100
# 7  Kulhudhuffushi      MV   6.62   73.07     84.22        66         100
# 8     Port Alfred      ZA -33.59   26.89     65.37        35           0
# 9          Hobart      AU -42.88  147.33     39.00        93          20
#
#    Wind Speed      Current Description  Rain(inches)  Snow(inches)
# 0       14.99  light intensity drizzle          0.00             0
# 1       16.11                clear sky          0.00             0
# 2        9.73                clear sky          0.00             0
# 3        8.05                  drizzle          0.00             0
# 4       18.34              shower rain          0.00             0
# 5       12.75                clear sky          0.00             0
# 6        8.41          overcast clouds          0.00             0
# 7        2.89          overcast clouds          0.00             0
# 8       12.71                clear sky          0.00             0
# 9        4.70               light rain          0.25             0

# %%
# Create the output file (CSV)
output_data_file = "weather_data/WeatherPy_database.csv"

# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
